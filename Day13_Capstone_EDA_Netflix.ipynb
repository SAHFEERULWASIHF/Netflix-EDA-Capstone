# %%
## 🎬 Project: Netflix Movies and TV Shows

# **Goal:** Explore and analyze the Netflix dataset to identify trends in
# content types, genres, countries, and release timelines. 
# Discover what dominates the platform—movies or TV shows,
# and what kind of content has increased over the years.

# **Tools:** Pandas, Matplotlib, Seaborn

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("../CSV's/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include='all')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %%
df['date_added'] = df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added']) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1714
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (8807, 12)

# %%
df['director'] = df['director'].fillna('No director info')
df['cast'] = df['cast'].fillna('No cast info')
df['country'] = df['country'].fillna('No country info')

# %%
type(df.release_year[0])
# Out:
# numpy.int64

# %%
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
df['day_name'] = df['date_added'].dt.day_name()
df['release_year'] = df['release_year'].astype('int')
df['content_age'] = df['year_added'] - df['release_year']
df.head(3)
# Out:
#   show_id     type                 title          director  \
# 0      s1    Movie  Dick Johnson Is Dead   Kirsten Johnson
# 1      s2  TV Show         Blood & Water  No director info
# 2      s3  TV Show             Ganglands   Julien Leclercq
#
#                                                 cast          country  \
# 0                                       No cast info    United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  No country info
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
type(df.release_year[0])
# Out:
# numpy.int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  year_added    8797 non-null   float64
#  13  month_added   8797 non-null   float64
#  14  day_name      8797 non-null   object
#  15  content_age   8797 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
#count of movies vs tv series

movies_vs_series_count = df.groupby('type')['show_id'].count()
movies_vs_series_count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: show_id, dtype: int64

# %%
movies_vs_series_count.plot(kind= 'bar')
plt.title('Movies vs Series')
plt.xlabel("")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x = 'type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df['listed_in'].str.split(', ', expand=True).stack().value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Categories")
plt.xlabel("")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df, x = 'year_added', hue='type' , kde = True)
plt.title("Yearly conted added with type")
plt.xlabel("Year")
plt.ylabel("count")
plt.tight_layout()
plt.show()

# %%
top_countries = df['country'].value_counts().head(10)
top_countries
# Out:
# country
# United States      2818
# India               972
# No country info     831
# United Kingdom      419
# Japan               245
# South Korea         199
# Canada              181
# Spain               145
# France              124
# Mexico              110
# Name: count, dtype: int64

# %%
sns.barplot(x = top_countries.values, y = top_countries.index)
plt.title("Top 10 content produced countries")
plt.xlabel('')
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
df.content_age.mean()
# Out:
# np.float64(4.688416505626918)

# %%
sns.histplot(x=df.content_age, bins = 20, kde = True)
plt.title("Content age distribution")
plt.xlabel("Content age(Years)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x = 'month_added', hue='type')
plt.title("Seasonal trend monthwise")
plt.xlabel("month")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
dayOrder = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday','Sunday']
sns.countplot(data= df, x = 'day_name', order= dayOrder, hue = 'type')
plt.title('Weekly trend daywise')
plt.xlabel("")
plt.ylabel('Count')
plt.tight_layout()
plt.show()
